# %%
from engine.parser import csvreader
from engine.dataframe import dataframe
from engine.ops import functions

# %% [markdown]
# ## Parser

# %%
parse = csvreader()

# %%
movie_columns, movie_rows = parse.read_doc('data/movies.csv', ',')
rating_columns, rating_rows = parse.read_doc('data/ratings.csv', ',')
tags_columns, tags_rows = parse.read_doc('data/tags.csv', ',')

# %% [markdown]
# ## Dataframes

# %%
dfc = dataframe()

# %%
df_movies = dfc.create_frame(movie_columns, movie_rows, extract_year=True)
df_ratings = dfc.create_frame(rating_columns, rating_rows)
df_tags = dfc.create_frame(tags_columns, tags_rows)

# %% [markdown]
# ## Operations

# %%
ops = functions()

# %% [markdown]
# ### **Filter and data frame lenght**
# filter(self,df,columns,conditions,values,seperators=[])

# %%
out1 = ops.filter(df_movies, ['year'], ['='], [1995])

# %%
print(ops.df_len(out1))
# Out:
# 259

# %%
out2 = ops.filter(df_ratings, ['rating'], ['>'], [4.5])
print(ops.df_len(out2))
# Out:
# 13211

# %% [markdown]
# ### **Projection**
# select_columns(self,df,cols)

# %%
out3 = ops.select_columns(df_movies, ['movieId', 'title'])
print(out3.keys())
# Out:
# dict_keys(['movieId', 'title'])

# %%
out4 = ops.filter(df_movies,['movieId','year'],['>','<'],[25,1995])
print(ops.select_columns(out4,['title']))
# Out:
# {'title': ['Lamerica', 'Postman, The (Postino, Il)', 'Nobody Loves Me (Keiner liebt mich)', 'Taxi Driver', 'Boys of St. Vincent, The', 'Boomerang', 'Chungking Express (Chung Hing sam lam)', 'NeverEnding Story III, The', "Jupiter's Wife", 'Amateur', 'Beauty of the Day (Belle de jour)', 'Crumb', 'Love & Human Remains', 'Mute Witness', 'Nadja', 'Umbrellas of Cherbourg, The (Parapluies de Cherbourg, Les)', 'Browning Version, The', 'Burnt by the Sun (Utomlyonnye solntsem)', 'Before the Rain (Pred dozhdot)', 'Clerks', 'Disclosure', 'Drop Zone', 'Death and the Maiden', 'Dumb & Dumber (Dumb and Dumber)', 'Eat Drink Man Woman (Yin shi nan nu)', 'Exotica', 'Exit to Eden', 'Ed Wood', 'Farinelli: il castrato', 'Hoop Dreams', 'Heavenly Creatures', 'Houseguest', 'Immortal Beloved', 'I.Q.', 'Interview with the Vampire: The Vampire Chronicles', 'Junior', 'Star Wars: Episode IV - A New Hope', 'Little Women', 'Ladybird Ladybird', 'Like Water for Chocolate (Como agua para chocolate)', 'Legends of the Fall', 'My Crazy Life (Mi vida loca)', 'Love Affair', 'Madness of King George, The', "Mary Shelley's Frankenstein (Frankenstein)", 'Mixed Nuts', 'Milk Money', 'Miracle on 34th Street', "Nobody's Fool", 'Nell', 'New York Cop (Nyû Yôku no koppu)', 'Beyond Bedlam', 'Nina Takes a Lover', 'Natural Born Killers', 'Only You', 'Once Were Warriors', 'Léon: The Professional (a.k.a. The Professional) (Léon)', 'Pulp Fiction', 'Pushing Hands (Tui shou)', 'Priest', 'Quiz Show', 'Picture Bride (Bijo photo)', 'Queen Margot (Reine Margot, La)', 'Ready to Wear (Pret-A-Porter)', 'Three Colors: Red (Trois couleurs: Rouge)', 'Three Colors: Blue (Trois couleurs: Bleu)', 'Three Colors: White (Trzy kolory: Bialy)', 'Relative Fear', 'Swan Princess, The', 'Secret of Roan Inish, The', 'Specialist, The', 'Stargate', 'Santa Clause, The', 'Shawshank Redemption, The', 'Shallow Grave', 'Suture', 'Strawberry and Chocolate (Fresa y chocolate)', 'Sum of Us, The', 'To Live (Huozhe)', 'Star Trek: Generations', 'Tom & Viv', 'Vanya on 42nd Street', "What's Eating Gilbert Grape", 'War, The', 'Double Happiness', "Muriel's Wedding", 'Ace Ventura: Pet Detective', 'Adventures of Priscilla, Queen of the Desert, The', 'Backbeat', 'Bitter Moon', 'Bullets Over Broadway', 'Clear and Present Danger', 'Client, The', 'Corrina, Corrina', 'Crooklyn', 'Crow, The', 'Cobb', 'Flintstones, The', 'Forrest Gump', 'Four Weddings and a Funeral', 'I Like It Like That', 'I Love Trouble', 'It Could Happen to You', 'Jungle Book, The', 'Wonderful, Horrible Life of Leni Riefenstahl, The (Macht der Bilder: Leni Riefenstahl, Die)', 'Lion King, The', 'Little Buddha', "Wes Craven's New Nightmare (Nightmare on Elm Street Part 7: Freddy's Finale, A)", 'Mask, The', 'Maverick', 'Mrs. Parker and the Vicious Circle', 'Naked Gun 33 1/3: The Final Insult', 'Paper, The', 'Reality Bites', 'Red Rock West', 'Richie Rich', 'River Wild, The', 'Speed', 'Speechless', 'Timecop', 'True Lies', 'When a Man Loves a Woman', 'Wolf', 'Wyatt Earp', 'Man of No Importance, A', 'S.F.W.', 'Low Down Dirty Shame, A', 'Colonel Chabert, Le', 'Faster Pussycat! Kill! Kill!', "Jason's Lyric", 'Street Fighter', 'Highlander III: The Sorcerer (a.k.a. Highlander: The Final Dimension)', 'Federal Hill', '8 Seconds', 'Above the Rim', 'Addams Family Values', 'Age of Innocence, The', 'Airheads', 'Air Up There, The', 'Another Stakeout', 'Bad Girls', 'Barcelona', 'Being Human', 'Beverly Hillbillies, The', 'Beverly Hills Cop III', 'Black Beauty', 'Blink', 'Blown Away', 'Blue Chips', 'Blue Sky', 'Body Snatchers', 'Boxing Helena', 'Bronx Tale, A', 'Cabin Boy', 'Calendar Girl', "Carlito's Way", "City Slickers II: The Legend of Curly's Gold", 'Clean Slate', 'Cliffhanger', 'Coneheads', 'Color of Night', 'Cops and Robbersons', 'Cowboy Way, The', 'Dave', 'Dazed and Confused', 'Demolition Man', 'Even Cowgirls Get the Blues', 'Fatal Instinct', 'Farewell My Concubine (Ba wang bie ji)', 'Fearless', 'Fear of a Black Hat', 'With Honors', 'Flesh and Bone', "Widows' Peak", 'For Love ...

# %% [markdown]
# ### **Groupby**
# groupby(self, df, groupby_columns, agg_column, agg_type)

# %%
out5 = ops.groupby(df_ratings,['movieId'],['rating'],'sum')
print(ops.head(out5))
# Out:
# {'movieId': [1, 3, 6, 47, 50], 'rating_sum': [843.0, 169.5, 402.5, 807.0, 864.5]}

# %%
out6 = ops.groupby(df_movies,['movieId'],['title'],'sum')
print(out6)
# Out:
# Datatype error check the aggregation columns, type usage!

# %% [markdown]
# ### **Joins**
# join(self, df_left, df_right, on_columns, how='inner', left_suffix='', right_suffix='')
#
# order_rows(self,df,cols,type='asc',limit=None)

# %%
out7 = ops.join(df_movies,df_ratings,['movieId'],how='inner',left_suffix='_movies',right_suffix='_rating')
out7 = ops.order_rows(out7,['userId'],type='dsc',limit=5)
print(out7)
# Out:
# {'movieId_movies': [1, 6, 16, 32, 47], 'title': ['Toy Story', 'Heat', 'Casino', 'Twelve Monkeys (a.k.a. 12 Monkeys)', 'Seven (a.k.a. Se7en)'], 'genres': ['Adventure|Animation|Children|Comedy|Fantasy', 'Action|Crime|Thriller', 'Crime|Drama', 'Mystery|Sci-Fi|Thriller', 'Mystery|Thriller'], 'year': [1995, 1995, 1995, 1995, 1995], 'userId': [610, 610, 610, 610, 610], 'movieId_rating': [1, 6, 16, 32, 47], 'rating': [5.0, 5.0, 4.5, 4.5, 5.0]}

# %%
out8 = ops.join(df_movies,df_tags,on_columns=['movieId'],how='right',left_suffix='_movies',right_suffix='_tags')
out8 = ops.filter(out8,['year'],['='],[2000])

# %%
print(out8)
# Out:
# {'movieId_movies': [3273, 3273, 3317, 3408, 3408, 3481, 3481, 3512, 3515, 3536, 3536, 3566, 3566, 3578, 3578, 3578, 3578, 3578, 3578, 3578, 3578, 3793, 3793, 3793, 3793, 3793, 3793, 3859, 3859, 3897, 3897, 3897, 3897, 3910, 3910, 3911, 3911, 3948, 3948, 3949, 3949, 3949, 3951, 3967, 3983, 3988, 3994, 3994, 3994, 3994, 3994, 3994, 3994, 3994, 3996, 3996, 4015, 4019, 4024, 4025, 4027, 4029, 4034, 4034, 4077, 4144, 4144, 4144, 4144, 4144, 4144, 4144, 4144, 4144, 4144, 4144, 4144, 4144, 4144, 4144, 4144, 4144, 4144, 4160, 4171, 4226, 4226, 4226, 4226, 4226, 4226, 4226, 4226, 4226, 4226, 4226, 4226, 4226, 4259, 4347, 4380, 6820, 7022, 7022, 7022, 7022, 7022, 7022, 7022, 7022, 7022, 7022, 7932, 7932, 7932, 7932, 7932, 7932, 62336, 62336, 62336, 62336], 'title': ['Scream 3', 'Scream 3', 'Wonder Boys', 'Erin Brockovich', 'Erin Brockovich', 'High Fidelity', 'High Fidelity', 'Return to Me', 'Me Myself I', 'Keeping the Faith', 'Keeping the Faith', 'Big Kahuna, The', 'Big Kahuna, The', 'Gladiator', 'Gladiator', 'Gladiator', 'Gladiator', 'Gladiator', 'Gladiator', 'Gladiator', 'Gladiator', 'X-Men', 'X-Men', 'X-Men', 'X-Men', 'X-Men', 'X-Men', 'Eyes of Tammy Faye, The', 'Eyes of Tammy Faye, The', 'Almost Famous', 'Almost Famous', 'Almost Famous', 'Almost Famous', 'Dancer in the Dark', 'Dancer in the Dark', 'Best in Show', 'Best in Show', 'Meet the Parents', 'Meet the Parents', 'Requiem for a Dream', 'Requiem for a Dream', 'Requiem for a Dream', 'Two Family House', 'Billy Elliot', 'You Can Count on Me', 'How the Grinch Stole Christmas (a.k.a. The Grinch)', 'Unbreakable', 'Unbreakable', 'Unbreakable', 'Unbreakable', 'Unbreakable', 'Unbreakable', 'Unbreakable', 'Unbreakable', 'Crouching Tiger, Hidden Dragon (Wo hu cang long)', 'Crouching Tiger, Hidden Dragon (Wo hu cang long)', "Dude, Where's My Car?", 'Finding Forrester', 'House of Mirth, The', 'Miss Congeniality', 'O Brother, Where Art Thou?', 'State and Main', 'Traffic', 'Traffic', 'With a Friend Like Harry... (Harry, un ami qui vous veut du bien)', 'In the Mood For Love (Fa yeung nin wa)', 'In the Mood For Love (Fa yeung nin wa)', 'In the Mood For Love (Fa yeung nin wa)', 'In the Mood For Love (Fa yeung nin wa)', 'In the Mood For Love (Fa yeung nin wa)', 'In the Mood For Love (Fa yeung nin wa)', 'In the Mood For Love (Fa yeung nin wa)', 'In the Mood For Love (Fa yeung nin wa)', 'In the Mood For Love (Fa yeung nin wa)', 'In the Mood For Love (Fa yeung nin wa)', 'In the Mood For Love (Fa yeung nin wa)', 'In the Mood For Love (Fa yeung nin wa)', 'In the Mood For Love (Fa yeung nin wa)', 'In the Mood For Love (Fa yeung nin wa)', 'In the Mood For Love (Fa yeung nin wa)', 'In the Mood For Love (Fa yeung nin wa)', 'In the Mood For Love (Fa yeung nin wa)', 'In the Mood For Love (Fa yeung nin wa)', 'Widow of St. Pierre, The (Veuve de Saint-Pierre, La)', "Long Night's Journey Into Day", 'Memento', 'Memento', 'Memento', 'Memento', 'Memento', 'Memento', 'Memento', 'Memento', 'Memento', 'Memento', 'Memento', 'Memento', 'Memento', 'Luzhin Defence, The', 'Divided We Fall (Musíme si pomáhat)', 'Princess and the Warrior, The (Krieger und die Kaiserin, Der)', 'Ginger Snaps', 'Battle Royale (Batoru rowaiaru)', 'Battle Royale (Batoru rowaiaru)', 'Battle Royale (Batoru rowaiaru)', 'Battle Royale (Batoru rowaiaru)', 'Battle Royale (Batoru rowaiaru)', 'Battle Royale (Batoru rowaiaru)', 'Battle Royale (Batoru rowaiaru)', 'Battle Royale (Batoru rowaiaru)', 'Battle Royale (Batoru rowaiaru)', 'Battle Royale (Batoru rowaiaru)', 'Dark Days', 'Dark Days', 'Dark Days', 'Dark Days', 'Dark Days', 'Dark Days', 'FLCL', 'FLCL', 'FLCL', 'FLCL'], 'genres': ['Comedy|Horror|Mystery|Thriller', 'Comedy|Horror|Mystery|Thriller', 'Comedy|Drama', 'Drama', 'Drama', 'Comedy|Drama|Romance', 'Comedy|Drama|Romance', 'Drama|Romance', 'Comedy|Romance', 'Comedy|Drama|Romance', 'Comedy|Drama|Romance', 'Comedy|Drama', 'Comedy|Drama', 'Action|Adventure|Drama', 'Action|Adventure|Drama', 'Action|Adventure|Drama', 'Action|Adventure|Drama', 'Action| ...

# %% [markdown]
# ### Full functional Test

# %%
# Movies released after 2010 and find the average rating

df = ops.filter(df_movies, ['year'], ['>'], [2010])
df = ops.join(df, df_ratings, ['movieId'], how='inner')
df = ops.select_columns(df, ['movieId', 'rating'])
df = ops.groupby(df, ['movieId'], ['rating'], 'avg')

# %%
print(df)
# Out:
# {'movieId': [82152, 83349, 83480, 83613, 83910, 84152, 84273, 84374, 84392, 84414, 84601, 84615, 84637, 84772, 84942, 84944, 84950, 84954, 85020, 85022, 85025, 85056, 85131, 85213, 85261, 85367, 85397, 85399, 85414, 85438, 85510, 85796, 85881, 86014, 86059, 86190, 86293, 86295, 86298, 86320, 86332, 86355, 86487, 86548, 86593, 86628, 86644, 86815, 86817, 86833, 86835, 86880, 86882, 86898, 86911, 87028, 87192, 87222, 87232, 87306, 87430, 87483, 87485, 87520, 87522, 87529, 87660, 87867, 87869, 87876, 88069, 88108, 88125, 88129, 88140, 88163, 88179, 88235, 88267, 88272, 88356, 88405, 88515, 88672, 88744, 88746, 88785, 88810, 88812, 88932, 88954, 89030, 89039, 89085, 89087, 89090, 89118, 89190, 89305, 89343, 89386, 89388, 89427, 89470, 89492, 89586, 89745, 89753, 89759, 89761, 89774, 89804, 89837, 89840, 89862, 89864, 89898, 89904, 89945, 90057, 90249, 90343, 90345, 90357, 90374, 90376, 90403, 90405, 90428, 90430, 90439, 90469, 90471, 90522, 90524, 90528, 90531, 90576, 90600, 90603, 90630, 90647, 90717, 90719, 90738, 90746, 90809, 90863, 90866, 90888, 90890, 90943, 91077, 91079, 91094, 91104, 91126, 91128, 